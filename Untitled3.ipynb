# %% [markdown]
# <a href="https://colab.research.google.com/github/SrijaKandese21uari200/HULK/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import necessary libraries
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Flatten, MaxPooling2D, Dropout
from keras.utils import to_categorical

# Load dataset
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# Reshape data to fit model
train_images = train_images.reshape(60000, 28, 28, 1)
test_images = test_images.reshape(10000, 28, 28, 1)

# One-hot encode target column
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

# Create model
model = Sequential([
  Conv2D(32, kernel_size=3, activation='relu', input_shape=(28,28,1)),
  MaxPooling2D(pool_size=2),
  Dropout(0.2),
  Flatten(),
  Dense(10, activation='softmax')
])

# Compile model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train model
history = model.fit(train_images, train_labels, validation_data=(test_images, test_labels), epochs=100, batch_size=256)

# Evaluate model
loss, accuracy = model.evaluate(test_images, test_labels)
print(f"Test accuracy: {accuracy*100:.2f}%")

# Plot results
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'], label='Accuracy (training data)')
plt.plot(history.history['val_accuracy'], label='Accuracy (validation data)')
plt.title('Accuracy over epochs')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(loc="upper left")
plt.show()

model.summary()
# Out:
# ...
# 11490434/11490434 [==============================] - 0s 0us/step
# Epoch 1/100
# 235/235 [==============================] - 12s 19ms/step - loss: 2.0091 - accuracy: 0.8946 - val_loss: 0.2470 - val_accuracy: 0.9677
# Epoch 2/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.2533 - accuracy: 0.9595 - val_loss: 0.1299 - val_accuracy: 0.9757
# Epoch 3/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.1392 - accuracy: 0.9701 - val_loss: 0.1042 - val_accuracy: 0.9765
# Epoch 4/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0965 - accuracy: 0.9758 - val_loss: 0.0880 - val_accuracy: 0.9789
# Epoch 5/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0752 - accuracy: 0.9787 - val_loss: 0.0844 - val_accuracy: 0.9779
# Epoch 6/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0591 - accuracy: 0.9819 - val_loss: 0.0771 - val_accuracy: 0.9805
# Epoch 7/100
# ...
